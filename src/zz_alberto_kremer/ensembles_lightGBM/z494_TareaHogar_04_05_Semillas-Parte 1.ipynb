# %% [markdown]
# # Tarea para el Hogar 04
#
# ## 5º Corrida: Selección de 12 modelos y aplicación de 5 semillas.
# ## Total: 60 experimentos
#
# #### A. En la 4º corrida decido dejar de probar hiperparámetros para realizar una evaluación de los modelos obtenidos.
#
# #### B. Hago una selección de 12 modelos según el siguiente criterio:
#
#  1. Ordeno la totalidad de modelos explorados por AUC de mayor a menor.
#  2. Tomo los 5 modelos de mayor AUC obtenido.
#  3. Tomo 5 modelos con hiperparámetros diferentes tomados entre los 30 modelos siguientes de mayor AUC.
#  3. Tomo 2 modelos con hiperparámetros diferentes tomados entre los 20 modelos siguientes de mayor AUC.
#
# #### C. Para cada uno de los 12 modelos, realizo una corrida multisemillas, con 5 pares de semillas cada uno, manteniendo el par para que las posteriores comparaciones sean representativas (1º semilla para el modelo, 2º semilla para el undersampling).
#
# #### D. En el próximo cuaderno, a estos mismos 12 modelos les realizaré otra corrida multisemillas con otros 5 pares de semillas cada. De esta manera, contaré para la toma de decisión y selección final corridas de 10 semillas por modelo.
#
# #### D. Las semillas, para posterior reproducibilidad, se generan a partir de una función de generación de primos a partir de mi semilla primigenia original.
#
# #### E. Modifico el cuaderno para reemplazar la realización de experimentos mediante iteraciones entre hiperparámetros por la exploración específica de cada modelo seleccionado.

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion sw Hiperparámetros lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}

# hago la descarga efectiva, llamando a descargar()
descargar  "dataset_pequeno.csv"

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Aug 28 04:50:55 PM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  671290 35.9 1473300    78.7 1473300  78.7
# Vcells 1242666  9.5 8388608    64.0 1978711  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5944

PARAM$semilla_primigenia <- 700001

# %%
# Generación reproducible de semillas adicionales
#******************************************************************************
# Ahora necesito 5 pares de semillas, por lo que genero 10 números aleatorios
# Asigno los números impares del listado al modelo y los pares al undersampling
#******************************************************************************

if (!require("primes")) install.packages("primes")
require("primes")

primos <- generate_primes(
  min = 100000,
  max = 1000000
)

set.seed(PARAM$semilla_primigenia)

semillas <- sample(
  primos,
  10
)

tb_semillas <- data.table(
  par = 1:5,
  semilla_modelo = semillas[c(1, 3, 5, 7, 9)],
  semilla_undersampling = semillas[c(2, 4, 6, 8, 10)]
)

tb_semillas
# Out:
#   par semilla_modelo semilla_undersampling
# 1 1   445507         569599
# 2 2   172153         164299
# 3 3   665633         805471
# 4 4   629989         464047
# 5 5   343087         371639

# %%
PARAM$kaggle$competencia <- "utn-2026-inicial"
PARAM$kaggle$cortes <- seq(9000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 2000,   #--- Decía 100. Pongo 2000 y luego que corte cuando encuentre no mejora.
  learning_rate= 0.10,  # >=0
  feature_fraction= 1.0, # 0 < ff <= 1.0
  num_leaves= 32, # integer >= 2
  min_data_in_leaf= 20 # integer >= 0
)

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
nrow(dataset_train)
ncol(dataset_train)

"clase01" %in% colnames(dataset_train)
"azar" %in% colnames(dataset_train)
"training" %in% colnames(dataset_train)

length(campos_buenos)

exists("dtrain")
# Out:
# [1] 164479
# [1] 156
# [1] TRUE
# [1] FALSE
# [1] FALSE
# [1] 154
# [1] FALSE

# %% [markdown]
# 2.2.5 Configuracion del Grid Search

# %%
#*** ESTA REEMPLAZA LA ORIGINAL POR UTILIZACIÓN DE SEMILLAS ***********

Estimar_AUC_lightgbm <- function(
    x,
    dtrain_actual,
    semilla_modelo
) {

  # Los hiperparámetros variables pisan/agregan
  # los valores definidos en param_fijos
  param_completo <- modifyList(
    PARAM$lgbm$param_fijos,
    x
  )

  # La semilla del modelo cambia en cada par
  param_completo$seed <- semilla_modelo

  # También fijo la semilla de R para que la validación cruzada sea comparable
  set.seed(semilla_modelo, kind = "L'Ecuyer-CMRG")

  # Cross validation
  modelocv <- lgb.cv(
    data = dtrain_actual,
    nfold = PARAM$hyperparametertuning$xval_folds,
    stratified = TRUE,
    param = param_completo,
    early_stopping_rounds = 100
  )

  AUC <- modelocv$best_score
  best_iter <- modelocv$best_iter

  message(
    format(Sys.time(), "%a %b %d %X %Y  "),
    "semilla modelo: ", semilla_modelo,
    "  AUC ", AUC,
    "  best_iter ", best_iter
  )

  rm(modelocv)

  gc(
    full = TRUE,
    verbose = FALSE
  )

  return(
    list(
      AUC = AUC,
      best_iter = best_iter
    )
  )
}

# %%
tb_modelos <- data.table(
  modelo = sprintf("M%02d", 1:12),

  num_leaves = rep(31L, 12),

  min_data_in_leaf = c(
    500L, 500L, 500L, 500L,
    500L, 500L, 500L, 500L,
    500L, 500L, 300L, 500L
  ),

  learning_rate = c(
    .01, .01, .01, .01,
    .01, .01, .01, .01,
    .01, .01, .01, .02
  ),

  feature_fraction = c(
    .60, .50, .50, .50,
    .50, .50, .60, .60,
    .60, .40, .60, .50
  ),

  bagging_fraction = c(
    .75, .90, .90, .90,
    .90, .90, .90, .90,
    .75, .75, .90, .75
  ),

  bagging_freq = rep(1L, 12),

  lambda_l2 = rep(0, 12),

  max_depth = rep(-1L, 12),

  min_gain_to_split = c(
    .01, .05, .01, .05,
    .05, .05, 0, 0,
    .01, .01, .01, 0
  ),

  lambda_l1 = c(
    0, 0, 0, 0,
    1, 1, 1, 0,
    1, 0, 0, 0
  ),

  min_sum_hessian_in_leaf = c(
    .001, .001, .001, 1,
    .001, 1, .001, 1,
    1, .001, .001, .001
  )
)

tb_modelos
# Out:
#    modelo num_leaves min_data_in_leaf learning_rate feature_fraction
# 1  M01    31         500              0.01          0.6
# 2  M02    31         500              0.01          0.5
# 3  M03    31         500              0.01          0.5
# 4  M04    31         500              0.01          0.5
# 5  M05    31         500              0.01          0.5
# 6  M06    31         500              0.01          0.5
# 7  M07    31         500              0.01          0.6
# 8  M08    31         500              0.01          0.6
# 9  M09    31         500              0.01          0.6
# 10 M10    31         500              0.01          0.4
# 11 M11    31         300              0.01          0.6
# 12 M12    31         500              0.02          0.5
#    bagging_fraction bagging_freq lambda_l2 max_depth min_gain_to_split
# 1  0.75             1            0         -1        0.01
# 2  0.90             1            0         -1        0.05
# 3  0.90             1            0         -1        0.01
# 4  0.90             1            0         -1        0.05
# 5  0.90             1            0         -1        0.05
# 6  0.90             1            0         -1        0.05
# 7  0.90             1            0         -1        0.00
# 8  0.90             1            0         -1        0.00
# 9  0.75             1            0         -1        0.01
# 10 0.75             1            0         -1        0.01
# 11 0.90             1            0         -1        0.01
# 12 0.75             1            0         -1        0.00
#    lambda_l1 min_sum_hessian_in_leaf
# 1  0         0.001
# 2  0         0.001
# 3  0         0.001
# 4  0         1.000
# 5  1         0.001
# 6  1         1.000
# 7  1         0.001
# 8  0         1.000
# 9  1         1.000
# 10 0         0.001
# 11 0         0.001
# 12 0         0.001

# %%
tb_evaluaciones <- merge(
  copy(tb_modelos)[, clave_cartesiana := 1L],
  copy(tb_semillas)[, clave_cartesiana := 1L],
  by = "clave_cartesiana",
  allow.cartesian = TRUE
)

tb_evaluaciones[, clave_cartesiana := NULL]

setorder(
  tb_evaluaciones,
  modelo,
  par
)

tb_evaluaciones[, AUC := NA_real_]
tb_evaluaciones[, best_iter := NA_integer_]

nrow(tb_evaluaciones)
# Out:
# [1] 60

# %%
head(tb_evaluaciones, 10)
# Out:
#    modelo num_leaves min_data_in_leaf learning_rate feature_fraction
# 1  M01    31         500              0.01          0.6
# 2  M01    31         500              0.01          0.6
# 3  M01    31         500              0.01          0.6
# 4  M01    31         500              0.01          0.6
# 5  M01    31         500              0.01          0.6
# 6  M02    31         500              0.01          0.5
# 7  M02    31         500              0.01          0.5
# 8  M02    31         500              0.01          0.5
# 9  M02    31         500              0.01          0.5
# 10 M02    31         500              0.01          0.5
#    bagging_fraction bagging_freq lambda_l2 max_depth min_gain_to_split
# 1  0.75             1            0         -1        0.01
# 2  0.75             1            0         -1        0.01
# 3  0.75             1            0         -1        0.01
# 4  0.75             1            0         -1        0.01
# 5  0.75             1            0         -1        0.01
# 6  0.90             1            0         -1        0.05
# 7  0.90             1            0         -1        0.05
# 8  0.90             1            0         -1        0.05
# 9  0.90             1            0         -1        0.05
# 10 0.90             1            0         -1        0.05
#    lambda_l1 min_sum_hessian_in_leaf par semilla_modelo semilla_undersampling
# 1  0         0.001                   1   445507         569599
# 2  0         0.001                   2   172153         164299
# 3  0         0.001                   3   665633         805471
# 4  0         0.001                   4   629989         464047
# 5  0         0.001                   5   343087         371639
# 6  0         0.001                   1   445507         569599
# 7  0         0.001                   2   172153         164299
# 8  0         0.001                   3   665633         805471
# 9  0         0.001                   4   629989         464047
# 10 0         0.001                   5   343087         371639
#    AUC best_iter
# 1  NA  NA
# 2  NA  NA
# 3  NA  NA
# 4  NA  NA
# 5  NA  NA
# 6  NA  NA
# 7  NA  NA
# 8  NA  NA
# 9  NA  NA
# 10 NA  NA

# %%
#Probamos las tablas creadas. En este experimento, con 12 modelos a probar cada
#uno con 5 semillas, debemos obtener: 12 / 5 / 60 / 60
nrow(tb_modelos)
nrow(tb_semillas)
nrow(tb_evaluaciones)
sum(is.na(tb_evaluaciones$AUC))
# Out:
# [1] 12
# [1] 5
# [1] 60
# [1] 60

# %%
#******* REEMPLAZO EL PROCESO ORIGINAL PARA ITERAR CON SEMILLAS *********

#------------------------------------------------------------
# EVALUACION MULTISEMILLA DE LOS 12 MODELOS FINALISTAS
# 12 modelos x 5 pares de semillas = 60 evaluaciones
#------------------------------------------------------------

archivo_checkpoint <- "tb_grid_search_05_multisemilla_parte1.txt"

#------------------------------------------------------------
# RECUPERO RESULTADOS SI EXISTE UN CHECKPOINT ANTERIOR
#------------------------------------------------------------

if (file.exists(archivo_checkpoint)) {
  tb_checkpoint <- fread(
    archivo_checkpoint
  )

  if (nrow(tb_checkpoint) == nrow(tb_evaluaciones)) {
    tb_evaluaciones[, AUC := tb_checkpoint$AUC]
    tb_evaluaciones[, best_iter := tb_checkpoint$best_iter]

    message(
      "Checkpoint recuperado: ",
      sum(!is.na(tb_evaluaciones$AUC)),
      " evaluaciones ya realizadas."
    )
  }
}

#------------------------------------------------------------
# RECORRO LOS 5 PARES DE SEMILLAS
#------------------------------------------------------------

for (p in 1:nrow(tb_semillas)) {
  # Filas correspondientes a este par
  indices_par <- which(tb_evaluaciones$par == p)

  # Si las 12 evaluaciones del par ya están completas,
  # no vuelvo siquiera a construir el dtrain
  if (all(!is.na(tb_evaluaciones$AUC[indices_par])))

  {message("Par ", p, " ya estaba completo. Se omite.")
    next
  }

  #----------------------------------------------------------
  # TOMO LAS DOS SEMILLAS DEL PAR
  #----------------------------------------------------------

  semilla_modelo_actual <- tb_semillas[p, semilla_modelo]

  semilla_undersampling_actual <- tb_semillas[p, semilla_undersampling]


  message("==================================================")

  message("PAR ", p, " | semilla modelo = ", semilla_modelo_actual,
    " | semilla undersampling = ", semilla_undersampling_actual)

  message("==================================================")

  #----------------------------------------------------------
  # GENERO EL UNDERSAMPLING PARA ESTE PAR
  #----------------------------------------------------------

  set.seed(semilla_undersampling_actual, kind = "L'Ecuyer-CMRG")

  dataset_train[, azar := runif(nrow(dataset_train))]

  dataset_train[, training := 0L]

  dataset_train[azar <= PARAM$trainingstrategy$undersampling |
      clase_ternaria %in% c("BAJA+1", "BAJA+2"), training := 1L]

  #----------------------------------------------------------
  # CREO UN SOLO DTRAIN PARA ESTE PAR
  # Los 12 modelos utilizan exactamente los mismos registros
  #----------------------------------------------------------

  dtrain_actual <- lgb.Dataset(data = data.matrix(dataset_train[
        training == 1L, campos_buenos, with = FALSE]),
        label = dataset_train[training == 1L, clase01],
        free_raw_data = FALSE)

  message("Filas seleccionadas para este par: ", nrow(dtrain_actual))

  #----------------------------------------------------------
  # RECORRO LOS 12 MODELOS
  #----------------------------------------------------------

  for (m in tb_modelos$modelo) {
    i <- which(tb_evaluaciones$modelo == m & tb_evaluaciones$par == p)

    # Si este modelo ya estaba calculado,
    # por ejemplo después de recuperar un checkpoint,
    # no lo vuelvo a ejecutar
    if (!is.na(tb_evaluaciones[i, AUC]))
    {
      next
    }

    #--------------------------------------------------------
    # EXTRAIGO LOS HIPERPARAMETROS DEL MODELO
    #--------------------------------------------------------

    hiperparametros <- as.list(

      tb_evaluaciones[i,.(
          num_leaves,
          min_data_in_leaf,
          learning_rate,
          feature_fraction,
          bagging_fraction,
          bagging_freq,
          lambda_l2,
          max_depth,
          min_gain_to_split,
          lambda_l1,
          min_sum_hessian_in_leaf
        )])

    message("Evaluando ", m, " | par ", p)
    #--------------------------------------------------------
    # CROSS VALIDATION
    #--------------------------------------------------------

    resultado <- Estimar_AUC_lightgbm(
      x = hiperparametros,
      dtrain_actual = dtrain_actual,
      semilla_modelo = semilla_modelo_actual)
    #--------------------------------------------------------
    # GUARDO RESULTADOS
    #--------------------------------------------------------
    tb_evaluaciones[i, AUC := resultado$AUC]
    tb_evaluaciones[i, best_iter := resultado$best_iter]
    #--------------------------------------------------------
    # CHECKPOINT DESPUES DE CADA MODELO
    #--------------------------------------------------------
    fwrite(tb_evaluaciones, file = archivo_checkpoint, sep = "\t")

    message("Progreso total: ", sum(!is.na(tb_evaluaciones$AUC)),
      " / ", nrow(tb_evaluaciones))
  }

  #----------------------------------------------------------
  # LIBERO EL DTRAIN DEL PAR
  #----------------------------------------------------------
  rm(dtrain_actual)
  gc(full = TRUE, verbose = FALSE)
}
# Out:
# ==================================================
#
# PAR 1 | semilla modelo = 445507 | semilla undersampling = 569599
#
# ==================================================
#
# Filas seleccionadas para este par: 83357
#
# Evaluando M01 | par 1
#
# Fri Aug 28 05:28:49 PM 2026  semilla modelo: 445507  AUC 0.932199998492216  best_iter 734
#
# Progreso total: 1 / 60
#
# Evaluando M02 | par 1
#
# Fri Aug 28 05:30:53 PM 2026  semilla modelo: 445507  AUC 0.932167232962373  best_iter 758
#
# Progreso total: 2 / 60
#
# Evaluando M03 | par 1
#
# Fri Aug 28 05:33:11 PM 2026  semilla modelo: 445507  AUC 0.932154452452123  best_iter 786
#
# Progreso total: 3 / 60
#
# Evaluando M04 | par 1
#
# Fri Aug 28 05:35:23 PM 2026  semilla modelo: 445507  AUC 0.93222412092682  best_iter 785
#
# Progreso total: 4 / 60
#
# Evaluando M05 | par 1
#
# Fri Aug 28 05:37:37 PM 2026  semilla modelo: 445507  AUC 0.932149031171299  best_iter 805
#
# Progreso total: 5 / 60
#
# Evaluando M06 | par 1
#
# Fri Aug 28 05:39:53 PM 2026  semilla modelo: 445507  AUC 0.932167817067086  best_iter 811
#
# Progreso total: 6 / 60
#
# Evaluando M07 | par 1
#
# Fri Aug 28 05:41:50 PM 2026  semilla modelo: 445507  AUC 0.931862764505426  best_iter 808
#
# Progreso total: 7 / 60
#
# Evaluando M08 | par 1
#
# Fri Aug 28 05:43:39 PM 2026  semilla modelo: 445507  AUC 0.931698218569984  best_iter 762
#
# Progreso total: 8 / 60
#
# Evaluando M09 | par 1
#
# Fri Aug 28 05:45:29 PM 2026  semilla modelo: 445507  AUC 0.932057705346945  best_iter 795
#
# Progreso total: 9 / 60
#
# Evaluando M10 | par 1
#
# Fri Aug 28 05:47:38 PM 2026  semilla modelo: 445507  AUC 0.931845708789813  best_iter 879
#
# Progreso total: 10 / 60
#
# Evaluando M11 | par 1
#
# Fri Aug 28 05:49:20 PM 2026  semilla modelo: 445507  AUC 0.931590032835801  best_iter 735
#
# Progreso total: 11 / 60
#
# Evaluando M12 | par 1
#
# Fri Aug 28 05:50:32 PM 2026  semilla modelo: 445507  AUC 0.931914116190138  best_iter 407
#
# Progreso total: 12 / 60
#
# ==================================================
#
# PAR 2 | semilla modelo = 172153 | semilla undersampling = 164299
#
# ==================================================
#
# Filas seleccionadas para este par: 83405
#
# Evaluando M01 | par 2
#
# Fri Aug 28 05:52:35 PM 2026  semilla modelo: 172153  AUC 0.932330999619668  best_iter 894
#
# Progreso total: 13 / 60
#
# Evaluando M02 | par 2
#
# Fri Aug 28 05:54:55 PM 2026  semilla modelo: 172153  AUC 0.932534273970908  best_iter 872
#
# Progreso total: 14 / 60
#
# Evaluando M03 | par 2
#
# Fri Aug 28 05:57:14 PM 2026  semilla modelo: 172153  AUC 0.932577016175312  best_iter 882
#
# Progreso total: 15 / 60
#
# Evaluando M04 | par 2
#
# Fri Aug 28 05:59:19 PM 2026  semilla modelo: 172153  AUC 0.932372952275734  best_iter 715
#
# Progreso total: 16 / 60
#
# Evaluando M05 | par 2
#
# Fri Aug 28 06:01:44 PM 2026  semilla modelo: 172153  AUC 0.932412634221474  best_iter 842
#
# Progreso total: 17 / 60
#
# Evaluando M06 | par 2
#
# Fri Aug 28 06:04:04 PM 2026  semilla modelo: 172153  AUC 0.932470236769872  best_iter 833
#
# Progreso total: 18 / 60
#
# Evaluando M07 | par 2
#
# Fri Aug 28 06:06:09 PM 2026  semilla modelo: 172153  AUC 0.93271663497885  best_iter 843
#
# Progreso total: 19 / 60
#
# Evaluando M08 | par 2
#
# Fri Aug 28 06:08:09 PM 2026  semilla modelo: 172153  AUC 0.932304179375345  best_iter 835
#
# Progreso total: 20 / 60
#
# Evaluando M09 | par 2
#
# Fri Aug 28 06:10:09 PM 2026  semilla modelo: 172153  AUC 0.932340762092992  best_iter 882
#
# Progreso total: 21 / 60
#
# Evaluando M10 | par 2
#
# Fri Aug 28 06:12:10 PM 2026  semilla modelo: 172153  AUC 0.932476552433883  best_iter 817
#
# Progreso total: 22 / 60
#
# Evaluando M11 | par 2
#
# Fri Aug 28 06:14:02 PM 2026  semilla modelo: 172153  AUC 0.932193012563999  best_iter 858
#
# Progreso total: 23 / 60
#
# Evaluando M12 | par 2
#
# Fri Aug 28 06:15:15 PM 2026  semilla modelo: 172153  AUC 0.932588914801226  best_iter 414
#
# Progreso total: 24 / 60
#
# ==================================================
#
# PAR 3 | semilla modelo = 665633 | semilla undersampling = 805471
#
# ==================================================
#
# Filas seleccionadas para este par: 83577
#
# Evaluando M01 | par 3
#
# Fri Aug 28 06:16:58 PM 2026  semilla modelo: 665633  AUC 0.931800570004221  best_iter 751
#
# Progreso total: 25 / 60
#
# Evaluando M02 | par 3
#
# Fri Aug 28 06:19:09 PM 2026  semilla modelo: 665633  AUC 0.932529264286128  best_iter 822
#
# Progreso total: 26 / 60
#
# Evaluando M03 | par 3
#
# Fri Aug 28 06:21:14 PM 2026  semilla modelo: 665633  AUC 0.932492718161171  best_iter 753
#
# Progreso total: 27 / 60
#
# Evaluando M04 | par 3
#
# Fri Aug 28 06:23:23 PM 2026  semilla modelo: 665633  AUC 0.932633431159482  best_iter 796
#
# Progreso total: 28 / 60
#
# Evaluando M05 | par 3
#
# Fri Aug 28 06:25:47 PM 2026  semilla modelo: 665633  AUC 0.93240150725979  best_iter 876
#
# Progreso total: 29 / 60
#
# Evaluando M06 | par 3
#
# Fri Aug 28 06:28:10 PM 2026  semilla modelo: 665633  AUC 0.932443860077156  best_iter 873
#
# Progreso total: 30 / 60
#
# Evaluando M07 | par 3
#
# Fri Aug 28 06:30:03 PM 2026  semilla modelo: 665633  AUC 0.932225612125175  best_iter 807
#
# Progreso total: 31 / 60
#
# Evaluando M08 | par 3
#
# Fri Aug 28 06:32:00 PM 2026  semilla modelo: 665633  AUC 0.932021278466665  best_iter 820
#
# Progreso total: 32 / 60
#
# Evaluando M09 | par 3
#
# Fri Aug 28 06:34:06 PM 2026  semilla modelo: 665633  AUC 0.931785228593174  best_iter 905
#
# Progreso total: 33 / 60
#
# Evaluando M10 | par 3
#
# Fri Aug 28 06:36:08 PM 2026  semilla modelo: 665633  AUC 0.931920954842832  best_iter 825
#
# Progreso total: 34 / 60
#
# Evaluando M11 | par 3
#
# Fri Aug 28 06:37:58 PM 2026  semilla modelo: 665633  AUC 0.93231513864429  best_iter 788
#
# Progreso total: 35 / 60
#
# Evaluando M12 | par 3
#
# Fri Aug 28 06:39:16 PM 2026  semilla modelo: 665633  AUC 0.931761351895586  best_iter 439
#
# Progreso total: 36 / 60
#
# ==================================================
#
# PAR 4 | semilla modelo = 629989 | semilla undersampling = 464047
#
# ==================================================
#
# Filas seleccionadas para este par: 83435
#
# Evaluando M01 | par 4
#
# Fri Aug 28 06:41:05 PM 2026  semilla modelo: 629989  AUC 0.931490753718963  best_iter 784
#
# Progreso total: 37 / 60
#
# Evaluando M02 | par 4
#
# Fri Aug 28 06:43:22 PM 2026  semilla modelo: 629989  AUC 0.931841968731279  best_iter 837
#
# Progreso total: 38 / 60
#
# Evaluando M03 | par 4
#
# Fri Aug 28 06:45:22 PM 2026  semilla modelo: 629989  AUC 0.931812404323447  best_iter 731
#
# Progreso total: 39 / 60
#
# Evaluando M04 | par 4
#
# Fri Aug 28 06:47:41 PM 2026  semilla modelo: 629989  AUC 0.931733267862698  best_iter 848
#
# Progreso total: 40 / 60
#
# Evaluando M05 | par 4
#
# Fri Aug 28 06:50:13 PM 2026  semilla modelo: 629989  AUC 0.931976417638921  best_iter 928
#
# Progreso total: 41 / 60
#
# Evaluando M06 | par 4
#
# Fri Aug 28 06:52:38 PM 2026  semilla modelo: 629989  AUC 0.931891226994476  best_iter 884
#
# Progreso total: 42 / 60
#
# Evaluando M07 | par 4
#
# Fri Aug 28 06:54:44 PM 2026  semilla modelo: 629989  AUC 0.931785377813738  best_iter 841
#
# Progreso total: 43 / 60
#
# Evaluando M08 | par 4
#
# Fri Aug 28 06:56:35 PM 2026  semilla modelo: 629989  AUC 0.931466239009084  best_iter 773
#
# Progreso total: 44 / 60
#
# Evaluando M09 | par 4
#
# Fri Aug 28 06:58:41 PM 2026  semilla modelo: 629989  AUC 0.931993659593815  best_iter 885
#
# Progreso total: 45 / 60
#
# Evaluando M10 | par 4
#
# Fri Aug 28 07:00:39 PM 2026  semilla modelo: 629989  AUC 0.931704438804635  best_iter 797
#
# Progreso total: 46 / 60
#
# Evaluando M11 | par 4
#
# Fri Aug 28 07:02:22 PM 2026  semilla modelo: 629989  AUC 0.931074922732209  best_iter 735
#
# Progreso total: 47 / 60
#
# Evaluando M12 | par 4
#
# Fri Aug 28 07:03:40 PM 2026  semilla modelo: 629989  AUC 0.931280929309292  best_iter 435
#
# Progreso total: 48 / 60
#
# ==================================================
#
# PAR 5 | semilla modelo = 343087 | semilla undersampling = 371639
#
# ==================================================
#
# Filas seleccionadas para este par: 82976
#
# Evaluando M01 | par 5
#
# Fri Aug 28 07:05:47 PM 2026  semilla modelo: 343087  AUC 0.932819234533193  best_iter 934
#
# Progreso total: 49 / 60
#
# Evaluando M02 | par 5
#
# Fri Aug 28 07:08:06 PM 2026  semilla modelo: 343087  AUC 0.932995314374389  best_iter 870
#
# Progreso total: 50 / 60
#
# Evaluando M03 | par 5
#
# Fri Aug 28 07:10:22 PM 2026  semilla modelo: 343087  AUC 0.932983740986687  best_iter 853
#
# Progreso total: 51 / 60
#
# Evaluando M04 | par 5
#
# Fri Aug 28 07:12:42 PM 2026  semilla modelo: 343087  AUC 0.932926582337863  best_iter 871
#
# Progreso total: 52 / 60
#
# Evaluando M05 | par 5
#
# Fri Aug 28 07:15:16 PM 2026  semilla modelo: 343087  AUC 0.933193539624741  best_iter 959
#
# Progreso total: 53 / 60
#
# Evaluando M06 | par 5
#
# Fri Aug 28 07:17:37 PM 2026  semilla modelo: 343087  AUC 0.933185214533488  best_iter 881
#
# Progreso total: 54 / 60
#
# Evaluando M07 | par 5
#
# Fri Aug 28 07:19:36 PM 2026  semilla modelo: 343087  AUC 0.932988712183075  best_iter 833
#
# Progreso total: 55 / 60
#
# Evaluando M08 | par 5
#
# Fri Aug 28 07:21:28 PM 2026  semilla modelo: 343087  AUC 0.932996035684037  best_iter 794
#
# Progreso total: 56 / 60
#
# Evaluando M09 | par 5
#
# Fri Aug 28 07:23:31 PM 2026  semilla modelo: 343087  AUC 0.932831091021501  best_iter 908
#
# Progreso total: 57 / 60
#
# Evaluando M10 | par 5
#
# Fri Aug 28 07:25:31 PM 2026  semilla modelo: 343087  AUC 0.932920500946738  best_iter 812
#
# Progreso total: 58 / 60
#
# Evaluando M11 | par 5
#
# Fri Aug 28 07:27:09 PM 2026  semilla modelo: 343087  AUC 0.932601970717446  best_iter 724
#
# Progreso total: 59 / 60
#
# Evaluando M12 | par 5
#
# Fri Aug 28 07:28:17 PM 2026  semilla modelo: 343087  AUC 0.932078553655616  best_iter 373
#
# Progreso total: 60 / 60

# %%
# veo que tiene la tabla DESPUES de procesar
tb_evaluaciones

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
#********* NO EJECUTAR **********************************
#*** Primero analizar resultados entre semillas *********

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización de hiperparametros

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-04**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-04**  en caso de ser necesario.
